# %%
import pandas as pd
from plotnine import *

my_file = pd.read_table('gapminder.txt')

# %%
(ggplot(my_file) + aes(x='gdpPercap', y='lifeExp') + geom_point())
# Out:
# <ggplot: (11709132)>

# %%
# !ls
# Out:
# gapminder.txt
# GGplot session.ipynb
# LifeExpPlot.py
# PlotLifeExp.png
# PlotLifeExp2.png
# Python session Feb 24.ipynb
# Sunday morn Python session.ipynb
# Untitled.ipynb

# %%
### Make a plot using ggplot where x = pop and y = lifeExp
(ggplot(my_file) + aes(x='pop', y='lifeExp') + geom_point())
# Out:
# <ggplot: (-9223372036842987562)>

# %%
(ggplot(my_file) + aes(x='year', y='lifeExp', color='continent') + geom_point())
# Out:
# <ggplot: (-9223372036842702532)>

# %%
(ggplot(my_file) + aes(x='year', y='lifeExp', color='continent', by='country') + geom_line())
# Out:
# <ggplot: (12050068)>

# %%
(ggplot(my_file) + aes(x='year', y='lifeExp', color='continent', by='country') + geom_line(aes(color='continent')) + geom_point())
# Out:
# <ggplot: (12945181)>

# %%
countries = my_file[my_file.country.str.startswith('A')|
                    my_file.country.str.startswith('Z')]

# %%
countries
# Out:
#           country continent  year  lifeExp       pop     gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333    779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934    820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083    853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966    836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460    739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372    786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816    978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957    852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921    649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415    635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405    726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923    974.580338
# 12        Albania    Europe  1952   55.230   1282697   1601.056136
# ...

# %%
(ggplot(countries) + aes(x='year', y='lifeExp', color='continent') + 
 geom_line() + facet_wrap('country'))
# Out:
# <ggplot: (19169863)>

# %%
(ggplot(countries) + aes(x='gdpPercap', y='lifeExp', size='pop', color='continent') + labs(x='GDP') +
 geom_point())
# Out:
# <ggplot: (19485402)>
